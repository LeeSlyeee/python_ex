# %% [markdown]
# ## 위스퍼 음성 인식 기초

# %% [markdown]
# ### 목차
# -  위스퍼 개요
# -  위스퍼 설치 방법 및 기본 예제
# -  파이썬에서 위스퍼 SDK 사용하기

# %% [markdown]
# - openai 설치
# - whisper 설치
# - ffmpeg 설치

# %% [markdown]
# ### 설치 및 시작하기

# %%
#!pip install -U openai-whisper
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openai-whisper
#   Using cached openai_whisper-20250625.tar.gz (803 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting more-itertools (from openai-whisper)
#   Using cached more_itertools-10.8.0-py3-none-any.whl.metadata (39 kB)
# Collecting numba (from openai-whisper)
#   Downloading numba-0.60.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Requirement already satisfied: numpy in /Users/slyeee/Library/Python/3.9/lib/python/site-packages (from openai-whisper) (1.26.4)
# Requirement already satisfied: tiktoken in /Users/slyeee/Library/Python/3.9/lib/python/site-packages (from openai-whisper) (0.12.0)
# Requirement already satisfied: torch in /Users/slyeee/Library/Python/3.9/lib/python/site-packages (from openai-whisper) (2.8.0)
# Requirement already satisfied: tqdm in /Users/slyeee/Library/Python/3.9/lib/python/site-packages (from openai-whisper) (4.67.1)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba->openai-whisper)
#   Downloading llvmlite-0.43.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Requirement already satisfied: regex>=2022.1.18 in /Users/slyeee/Library/Python/3.9/lib/python/site-packages (from tiktoken->openai-whisper) (2026.1.15)
# Requirement already satisfied: requests>=2.26.0 in /Users/slyeee/Library/Python/3.9/lib/python/site-packages (from tiktoken->openai-whisper) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/slyeee/Library/Python/3.9/lib/python/site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/slyeee/Library/Python/3.9/lib/python/site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/slyeee/Library/Python/3.9/lib/python/site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/slyeee/Library/Python/3.9/lib/python/site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2025.11.12)
# Requirement already satisfied: filelock in /Library/Python/3.9/site-packages (from torch->openai-whisper) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/slyeee/Library/Python/3.9/lib/python/site-packages (from torch->openai-whisper) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/slyeee/Library/Python/3.9/lib/python/site-packages (from torch->openai-whisper) (1.14.0)
# Requirement already satisfied: networkx in /Users/slyeee/Library/Python/3.9/lib/python/site-packages (from torch->openai-whisper) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/slyeee/Library/Python/3.9/lib/python/site-packages (from torch->openai-whisper) (3.1.6)
# Requirement already satisfied: fsspec in /Users/slyeee/Library/Python/3.9/lib/python/site-packages (from torch->openai-whisper) (2025.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/slyeee/Library/Python/3.9/lib/python/site-packages (from sympy>=1.13.3->torch->openai-whisper) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/slyeee/Library/Python/3.9/lib/python/site-packages (from jinja2->torch->openai-whisper) (3.0.3)
# Using cached more_itertools-10.8.0-py3-none-any.whl (69 kB)
# Downloading numba-0.60.0-cp39-cp39-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 68.2 MB/s  0:00:00
# Downloading llvmlite-0.43.0-cp39-cp39-macosx_11_0_arm64.whl (28.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.8/28.8 MB 74.9 MB/s  0:00:00 eta 0:00:01
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=c6c243308ec1f6ca570e1a54861ff1ebcccced1edb7e5b67ae1b4b83130ed75d
#   Stored in directory: /Users/slyeee/Library/Caches/pip/wheels/8a/52/46/c497a169da69d4edcfe4e66e2f597ce258c334d74d371bf8c9
# Successfully built openai-whisper
# Installing collected packages: more-itertools, llvmlite, numba, openai-whisper
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [openai-whisper]m [numba]
# Successfully installed llvmlite-0.43.0 more-itertools-10.8.0 numba-0.60.0 openai-whisper-20250625
# Note: you may need to restart the kernel to use updated packages.

# %%
#!winget install ffmpeg -e --accept-source-agreements --accept-package-agreements
# Out:
#   Cell In[2], line 1
#     winget install ffmpeg -e --accept-source-agreements --accept-package-agreements
#            ^
# SyntaxError: invalid syntax

# %%
import whisper

print(whisper.__version__)

# %%
# 오디오 파일 다운로드
# !curl -o Winston_Church.ogg https://upload.wikimedia.org/wikipedia/commons/7/75/Winston_Churchill_-_Be_Ye_Men_of_Valour.ogg

# %% [markdown]
# ### base 모델 사용시

# %%
# 개인 폴더에서 작업하시는 경우 경로에 한글이 포함되면 에러가 날 확률이 높습니다.
# 1분 이상의 시간이 걸리는 경우가 많습니다.

# !whisper Winston_Church.ogg --model base

# %% [markdown]
# ### medium 모델 사용 후, 음성 스크립트 만들기

# %%
# medium은 10분 이상, large는 그 이상 걸릴 수 있으므로 더 정확하게 음성을 뽑아내고 싶다는 경우만 테스트 해 봅시다.
# medium 모델 사용
# !whisper Winston_Church.ogg --model medium

# large 모델 사용
# !whisper src/whisper/audio/Winston_Church.ogg --model large

# %% [markdown]
# ### 도움말 확인

# %%
# !whisper -h

# %% [markdown]
# ### Python에서 Whisper SDK 사용하기

# %%
import whisper  # Whisper 라이브러리 불러오기

# 필요에 따라 모델 크기 설정 (예: "tiny", "small", "medium", "large")
model_name = "base"  # 사용할 모델 이름 설정
try:
    # 모델 로드
    model = whisper.load_model(model_name)
except Exception as e:
    print(f"모델 '{model_name}' 로드 에러: {e}")  # 오류 메시지 출력
    exit(1)

# 오디오 파일 경로 설정
audio_file_path = "Winston_Church.ogg"
try:
    # 오디오 파일 필사(텍스트 변환)
    result = model.transcribe(audio_file_path)
    print('오디오의 텍스트 변환 결과:')
    print(result['text'])  # 변환된 텍스트 출력
except Exception as e:
    print(f"오디오 파일 '{audio_file_path}' 필사 에러: {e}")  # 오류 메시지 출력

# %%
#  whisper_test.py
import whisper  # Whisper 라이브러리 불러오기

# 필요에 따라 모델 설정 (예: "tiny", "small", "medium", "large")
model_name = "small"  # 사용할 모델을 medium으로 설정

try:
    # 모델 로드
    model = whisper.load_model(model_name)
except Exception as e:
    print(f"모델 '{model_name}' 로드 에러: {e}")  # 모델 로드 시 오류가 발생하면 에러 메시지 출력
    exit(1)

# 오디오 파일 경로 설정
audio_file_path = "Winston_Church.ogg"

try:
    # 오디오 파일을 영어로 필사
    result = model.transcribe(
        audio_file_path,
        language="en"  # 영어로 필사 설정
    )
    print("영어 변환 결과:")
    print(result["text"])  # 영어 필사 결과 출력

    # 오디오 파일을 중국어로 필사
    result = model.transcribe(
        audio_file_path,
        language="zh"  # 중국어로 필사 설정
    )
    print("중국어 변환 결과:")
    print(result["text"])  # 중국어 필사 결과 출력

    # 오디오 파일을 일본어로 필사
    result = model.transcribe(
        audio_file_path,
        language="ja"  # 일본어로 필사 설정
    )
    print("일본어 변환 결과:")
    print(result["text"])  # 일본어 필사 결과 출력

    # .. 기타 언어 필사 예제 추가 가능
except Exception as e:
    print(f"오디오 파일 '{audio_file_path}' 필사 에러: {e}")  # 필사 중 오류 발생 시 에러 메시지 출력

# %% [markdown]
# ## 위스퍼 텍스트 변환 최적화 기법

# %% [markdown]
# ### 목차
# - 오픈AI 음성-텍스트 API 사용하기
# - 위스퍼 텍스트 변환 개선하기

# %%
# !pip install httpx

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv
load_dotenv(override=True)

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
client = OpenAI()

# 오디오 파일 경로 정의
audio_file_path = os.path.abspath("Winston_Church.ogg")

# 사용할 모델 정의
model = "whisper-1"  # Whisper-1 모델 사용

# 오디오 파일을 바이너리 모드로 열기
with open(audio_file_path, 'rb') as audio_file:
    # 오디오 파일 전사(텍스트 변환)
    transcript = client.audio.transcriptions.create(
        model=model,
        file=audio_file
    )
    print(transcript.text)  # 전사된 텍스트 출력

# %%
# 오디오 파일 경로 정의
audio_file_path = os.path.abspath("Winston_Church.ogg")

# 사용할 모델 정의
model = "whisper-1"  # Whisper-1 모델 사용

# 오디오 파일을 바이너리 모드로 열기
with open(audio_file_path, 'rb') as audio_file:
    # 오디오 파일 번역 및 텍스트 변환
    transcript = client.audio.translations.create(
        model=model,
        file=audio_file,
    )
    print(transcript.text)  # 번역된 텍스트 출력

# %% [markdown]
# ### 위스퍼 텍스트 변환 개선하기

# %% [markdown]
# ### 데이터 준비

# %% [markdown]
# !curl -o cypher.mp3 https://raw.githubusercontent.com/LDJWJ/OpenAIGPTForPythonDevelopersFiles/main/audio/cypher.mp3

# %%
# 오디오 파일 다운로드
# !curl -o cypher.mp3 https://raw.githubusercontent.com/LDJWJ/OpenAIGPTForPythonDevelopersFiles/main/audio/cypher.mp3

# %%
# 오디오 파일 경로 정의
audio_file_path = os.path.abspath(
    "cypher.mp3"  # 오디오 파일 경로를 설정합니다.
)

# 모델 정의
model = "whisper-1"  # Whisper-1 모델을 사용합니다.

# 프롬프트 정의
prompt = "Cypher"  # 올바른 철자를 힌트로 제공하기 위해 'Cypher'를 프롬프트로 설정합니다.

# 오디오 파일을 바이너리 모드로 열기
with open(audio_file_path, 'rb') as audio_file:
    # 오디오 파일 전사
    transcript = client.audio.transcriptions.create(
        model=model,
        file=audio_file,
        prompt=prompt
    )

# 전사된 텍스트 출력
print(transcript.text)

# %%
# 오디오 파일 경로 정의
audio_file_path = os.path.abspath(
    "cypher.mp3"  # 오디오 파일의 경로를 설정합니다.
)

# 모델 정의
model = "whisper-1"  # Whisper-1 모델을 사용합니다.

# 오디오 파일을 바이너리 모드로 열기
with open(audio_file_path, 'rb') as audio_file:
    # 오디오 파일 전사(Transcription)
    transcript = client.audio.transcriptions.create(
        model=model,
        file=audio_file
    )

# GPT-4.1-mini를 사용하여 텍스트 후처리(post-processing)
system_prompt = """당신은 영화 전문가입니다.
오디오 파일의 전사를 수정하는 것이 당신의 역할입니다.
예를 들어, 'Cipher' 또는 'Cypher'의 단어는 'Cyber'로 수정해야 합니다."""

# 모델 정의
model = "gpt-4.1-mini"  # GPT-4o 모델을 사용합니다.

# 텍스트 후처리
response = client.chat.completions.create(
    model=model,
    messages=[
        {
            "role": "system",
            "content": system_prompt  # 시스템 프롬프트로 후처리 작업을 설정합니다.
        },
        {
            "role": "user",
            "content": transcript.text  # Whisper 전사 텍스트를 사용자 입력으로 전달합니다.
        }
    ]
)

# 수정된 텍스트 출력
print(response.choices[0].message.content)  # GPT-4.1-mini로 수정한 텍스트를 출력합니다.
